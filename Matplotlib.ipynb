# %% [markdown]
# <a href="https://colab.research.google.com/github/NuzhatJabeen/Practice-Codes-of-Panda-/blob/main/Matplotlib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
            #Draw a line from (0,0) to (6,250)

import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([0,6])       #Points on the x axis (Horizontal Axis)
ypoints=np.array([0,250])     #Points on the y axis  (Vertical Axis)
plt.plot(xpoints,ypoints)     #Plot the points of x and y
plt.show()                    #Show the points of x and y on a graph

            #Draw two points in the diagram, one at position (1,3) and one in position (8,10)

import matplotlib.pyplot as plt
import numpy as np
xpoints=np.array([1,3])       #Points on the x axis (Horizontal Axis)
ypoints=np.array([8,10])      #Points on the y axis  (Vertical Axis)
plt.plot(xpoints,ypoints,'o') #Plot the points of x and y and 'o' shows the specific points of the two co-ordinates
plt.show()                    #Show the points of x and y on a graph

             #Drawing Multiple points on the graph

import matplotlib.pyplot as plt
import numpy as np
xpoints=([1,2,6,8])        #Points on the x axis (Horizontal Axis)
ypoints=([3,8,1,10])       #Points on the y axis  (Vertical Axis) 
plt.plot(xpoints,ypoints)  #Plot the points of x and y
plt.show()                 #Show the points of x and y on a graph

            #Default X-Points

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10,5,7])  #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints)         #Plot the points of y
plt.show()                #Show the points of x and y on a graph

          #Markers in Matplotlib

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])  #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,marker='o')  #Plot the points of y and plot each point with a 'circle'
plt.show()                    #Show the points of x and y on a graph

        #Format Strings fmt- marker|line|colour

import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])   #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints, 'o:r')            #Plot the points of y and plot each point with a 'circle' and the colour will be'red'
plt.show()                          #Show the points of x and y on a graph

        #Marker Size

import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])   #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,marker='o',ms=20)  #Plot the points of y,plot each point with a 'circle' and the 'markersize' will be 20
plt.show()                          #Show the points of x and y on a graph

      #Marker Colour

import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])   #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,marker='o',ms=20,mec='r')  #Plot the points of y,plot each point with a 'circle','markersize' will be 20 and 'markeredgecolour' will be'red'
plt.show() #Show the points of x and y on a graph

    #Marker Face Colour

import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])   #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,marker='o',ms=20,mfc='r')  #Plot the points of y,plot each point with a 'circle','markersize' will be 20 and 'markerfacecolour' will be'red'
plt.show() #Show the points of x and y on a graph

    #Combination of Marker Edge Colour and Marker Face Colour

import matplotlib.pyplot as plt
import numpy as np
ypoints = np.array([3, 8, 1, 10])   #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,marker='o',ms=20,mec='r',mfc='r')  #Plot the points of y,plot each point with a 'circle','markersize' will be 20,both the'markeredgecolour and'markerfacecolour' will be'red'
plt.show() #Show the points of x and y on a graph

     #Using a Linestyle

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])     #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,linestyle='dotted') #Plot the points of y and use a 'dotted' linestyle
plt.show() #Show the points of x and y on a graph

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])       #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,linestyle='dashed')  #Plot the points of y and use a 'dashed' linestyle
plt.show() #Show the points of x and y on a graph

      #Using a Linestyle with Shorter Syntax

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])     #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,ls=':')  #Shorter Syntax of 'dotted' line is : and 'linespace' is ls
plt.show()   #Show the points of x and y on a graph

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])    #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,ls='--')   #Shorter Syntax of 'dashed' line is -- and 'linespace' is ls
plt.show()        #Show the points of x and y on a graph

       #Using a Line Colour

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])   #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,color='r')  #Plot the points with red colour
plt.show()    #Show the points of x and y on a graph

      #Using a Line Width

import matplotlib.pyplot as plt
import numpy as np
ypoints=np.array([3,8,1,10])    #Points on the y axis  (Vertical Axis) 
plt.plot(ypoints,linewidth='20.5')  #Linewidth of the graph is 20.5
plt.show()    #Show the points of x and y on a graph

        #Drawing Multiple lines on the same graph

import matplotlib.pyplot as plt
import numpy as np
y1=np.array([3,8,1,10])  #Assign the points of y1
y2=np.array([6,2,7,11])  #Assign the points of y2
plt.plot(y1)             #Plot the points of y1
plt.plot(y2)             #Plot the points of y2
plt.show()               #Show the points of x and y on a graph

        #Draw two lines by specifiyng the x and y points for both lines

import matplotlib.pyplot as plt
import numpy as np
x1 = np.array([0, 1, 2, 3])   #Assign the points of x1
y1 = np.array([3, 8, 1, 10])  #Assign the points of y1
x2 = np.array([0, 1, 2, 3])   #Assign the points of x2
y2 = np.array([6, 2, 7, 11])  #Assign the points of y2
plt.plot(x1, y1, x2, y2)      #Plot the points of x and y
plt.show()                    #Show the points of x and y on a graph

        #Create labels for a plot

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.plot(x, y)   #Plot the points of x and y
plt.xlabel("Average Pulse")  #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage") #Label the y axis as "Calorie Burnage"
plt.show()                    #Show the points of x and y on a graph

        #Create title for a plot

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.plot(x, y)   #Plot the points of x and y
plt.title("Sports Watch Data") #Title of the graph "Sports Watch Data"
plt.xlabel("Average Pulse")  #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage") #Label the y axis as "Calorie Burnage"
plt.show()                    #Show the points of x and y on a graph

    #Font Properties of the 'Title' and 'Labels'

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
font1={'family':'Times New Roman','color':'blue','size':20} 
font2={'family':'Times New Roman','color':'darkred','size':15}
plt.title("Sports Watch Data",fontdict=font1) #Title of the graph "Sports Watch Data" using font1
plt.xlabel("Average Pulse",fontdict=font2)  #Label the x axis as "Average Pulse" using font2
plt.ylabel("Calorie Burnage",fontdict=font2) #Label the y axis as "Calorie Burnage" using font2
plt.plot(x,y) #Plot the points of x and y
plt.show()  #Show the points of x and y on a graph

      #Shift the title to the left

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.title("Sports Watch Data",loc='left')  #Shift the title of the graph "Sports Watch Data" to the left
plt.xlabel("Average Pulse")      #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage")    #Label the y axis as "Calorie Burnage" 
plt.plot(x,y)  #Plot the points of x and y
plt.show()     #Show the points of x and y on a graph

      #Add grid lines on the plot

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.title("Sports Watch Data")  #Title of the graph "Sports Watch Data" 
plt.xlabel("Average Pulse")      #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage")    #Label the y axis as "Calorie Burnage" 
plt.plot(x,y)  #Plot the points of x and y
plt.grid() #Add grid on the graph
plt.show()  #Show the points of x and y on a graph

      #Add grid lines to a specific axis

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.title("Sports Watch Data")  #Title of the graph "Sports Watch Data" 
plt.xlabel("Average Pulse")      #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage")    #Label the y axis as "Calorie Burnage" 
plt.plot(x,y)  #Plot the points of x and y
plt.grid(axis='x') #Showing grid to the x axis only
plt.show()  #Show the points of x and y on a graph

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.title("Sports Watch Data")  #Title of the graph "Sports Watch Data" 
plt.xlabel("Average Pulse")      #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage")    #Label the y axis as "Calorie Burnage" 
plt.plot(x,y)  #Plot the points of x and y
plt.grid(axis='y') #Showing grid to the y axis only
plt.show()  #Show the points of x and y on a graph

      #Using the Properties of Grid

import matplotlib.pyplot as plt
import numpy as np 
x = np.array([80, 85, 90, 95, 100, 105, 110, 115, 120, 125])    #Assign the points of x 
y = np.array([240, 250, 260, 270, 280, 290, 300, 310, 320, 330]) #Assign the points of y
plt.title("Sports Watch Data")  #Title of the graph "Sports Watch Data" 
plt.xlabel("Average Pulse")      #Label the x axis as "Average Pulse"
plt.ylabel("Calorie Burnage")    #Label the y axis as "Calorie Burnage" 
plt.plot(x,y)  #Plot the points of x and y
plt.grid(color='green',linestyle='--',linewidth=0.5) #Showing grid to the x axis only
plt.show()  #Show the points of x and y on a graph

      #Using Subplots

import matplotlib.pyplot as plt
import numpy as np 

#Plot 1 
x= np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)   #Plot has 1 row, 2 coloumns and this plot is the 'first' plot
plt.plot(x,y)          #Plot the points of x and y

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)   #Plot has 1 row, 2 coloumns and this plot is the 'second' plot
plt.plot(x,y)          #Plot the points of x and y
plt.show()

      #Add 'Title' to the 'Subplots'

import matplotlib.pyplot as plt
import numpy as np 

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.show()

      #Adding 'Suptitle' to the 'Subplots'

import matplotlib.pyplot as plt
import numpy as np 

#plot 1:
x = np.array([0, 1, 2, 3])
y = np.array([3, 8, 1, 10])
plt.subplot(1, 2, 1)
plt.plot(x,y)
plt.title("SALES")

#plot 2:
x = np.array([0, 1, 2, 3])
y = np.array([10, 20, 30, 40])
plt.subplot(1, 2, 2)
plt.plot(x,y)
plt.title("INCOME")
plt.suptitle("MY SHOP")
plt.show()

      #Creating Scatter Plots

import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)
plt.show()

       #Comparing Plots

import matplotlib.pyplot as plt
import numpy as np

#Age and speed of 13 cars
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y)

#Age and speed of 15 cars
x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y)
plt.show()

      #Adding colours to plots
      
import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
plt.scatter(x, y, color = 'red')

x = np.array([2,2,8,1,15,8,12,9,7,3,11,4,7,14,12])
y = np.array([100,105,84,105,90,99,90,95,94,100,79,112,91,80,85])
plt.scatter(x, y, color = 'green')
plt.show()  

      #Colour each dot

import matplotlib.pyplot as plt
import numpy as np
x = np.array([5,7,8,7,2,17,2,9,4,11,12,9,6])
y = np.array([99,86,87,88,111,86,103,87,94,78,77,85,86])
colors = np.array(["red","green","blue","yellow","pink","black","orange","purple","beige","brown","gray","cyan","magenta"])
plt.scatter(x, y, c=colors)
plt.show()

      #Creating Bars

import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y)
plt.show()

      #Creating Horizontal Bars

import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x,y)
plt.show()

     #Bar Colours

import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y,color="red")
plt.show()

      #Bar Width

import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.bar(x,y,width=0.1)
plt.show()

    #Horizontal Bar Width

import matplotlib.pyplot as plt
import numpy as np
x = np.array(["A", "B", "C", "D"])
y = np.array([3, 8, 1, 10])
plt.barh(x,y,height=0.1)
plt.show()

      #Creating Histograms

import matplotlib.pyplot as plt
import numpy as np
x = np.random.normal(170, 10, 250)
plt.hist(x)
plt.show() 

      #Creating Pie Charts

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
plt.pie(y)
plt.show()

      #Labelling the Pie Charts

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.show()

      #Start Angle in Pie Charts

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels, startangle = 90)
plt.show() 

      #Using Explodes

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode)
plt.show() 

      #Using Shadows

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
myexplode = [0.2, 0, 0, 0]
plt.pie(y, labels = mylabels, explode = myexplode, shadow = True)
plt.show()

    #Using Colours

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
mycolors = ["k", "m", "b", "g"]
plt.pie(y, labels = mylabels, colors = mycolors)
plt.show() 

    #Adding Legends

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.legend()
plt.show() 

    #Legend with Header

import matplotlib.pyplot as plt
import numpy as np
y = np.array([35, 25, 25, 15])
mylabels = ["Apples", "Bananas", "Cherries", "Dates"]
plt.pie(y, labels = mylabels)
plt.legend(title = "Four Fruits:")
plt.show()
# Out:
# WARNING:matplotlib.font_manager:findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
# WARNING:matplotlib.font_manager:findfont: Font family ['Times New Roman'] not found. Falling back to DejaVu Sans.
